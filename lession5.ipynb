# %%
import requests
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print('連線成功')
    all_data = response.json()
    print(type(all_data))
else:
    print(f'連線失敗:{response.status_code}')
# Out:
# 連線成功
# <class 'list'>

# %%
import pandas as pd
dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    0     大安區  2023-05-27 15:34:03  \
# 1       YouBike2.0_復興南路二段273號前   21    0     大安區  2023-05-27 15:45:15
# 2         YouBike2.0_國北教大實小東側門   16    1     大安區  2023-05-27 15:45:15
# 3            YouBike2.0_和平公園東側   11    0     大安區  2023-05-27 15:23:04
# 4         YouBike2.0_辛亥復興路口西北側   16    2     大安區  2023-05-27 15:43:15
# ...                        ...  ...  ...     ...                  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   28    臺大專區  2023-05-27 15:46:15
# 1276        YouBike2.0_臺大黑森林西側   20   11    臺大專區  2023-05-27 15:45:16
# 1277        YouBike2.0_臺大獸醫館南側   24   11    臺大專區  2023-05-27 15:43:16
# 1278      YouBike2.0_臺大新體育館東南側   40   15    臺大專區  2023-05-27 15:37:14
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    5  臺大公館校區  2023-05-27 15:37:14
#
#                  ar  bemp act
# 0       復興南路二段235號前    25   1
# 1      復興南路二段273號西側    21   1
# 2       和平東路二段96巷7號    14   1
# 3     和平東路二段118巷33號    11   1
# 4        復興南路二段368號    14   1
# ...             ...   ...  ..
# 1275       臺大圖書館西南側     2   1
# 1276        臺大霖澤館南側     9   1
# 1277       臺大獸醫系館南側    13   1
# 1278        臺大體育館東側    25   1
# 1279       明達館北側前空地    13   1
#
# [1280 rows x 8 columns]

# %%
#選取欄位
dataFrame[0:100]
# Out:
#                          sna  tot  sbi sarea                 mday
# 0         YouBike2.0_捷運科技大樓站   28    0   大安區  2023-05-27 15:34:03  \
# 1     YouBike2.0_復興南路二段273號前   21    0   大安區  2023-05-27 15:45:15
# 2       YouBike2.0_國北教大實小東側門   16    1   大安區  2023-05-27 15:45:15
# 3          YouBike2.0_和平公園東側   11    0   大安區  2023-05-27 15:23:04
# 4       YouBike2.0_辛亥復興路口西北側   16    2   大安區  2023-05-27 15:43:15
# ..                       ...  ...  ...   ...                  ...
# 95  YouBike2.0_捷運忠孝新生站(4號出口)   34    3   大安區  2023-05-27 15:43:15
# 96           YouBike2.0_大安高工   23    7   大安區  2023-05-27 15:44:14
# 97  YouBike2.0_捷運忠孝新生站(3號出口)   23    3   大安區  2023-05-27 15:45:15
# 98           YouBike2.0_瑠公公園   20    4   大安區  2023-05-27 15:42:13
# 99         YouBike2.0_敦化市民路口   23    4   大安區  2023-05-27 15:41:16
#
#                   ar  bemp act
# 0        復興南路二段235號前    25   1
# 1       復興南路二段273號西側    21   1
# 2        和平東路二段96巷7號    14   1
# 3      和平東路二段118巷33號    11   1
# 4         復興南路二段368號    14   1
# ..               ...   ...  ..
# 95          忠孝新生路口北側    30   1
# 96      復興南路二段52號(前)    15   1
# 97       忠孝東路三段與10巷口    20   1
# 98  忠孝東路四段49巷4弄/大安路口    15   1
# 99     敦化南路1段158號(前)    16   1
#
# [100 rows x 8 columns]

# %%
#同時選取欄列
#loc[index,column],iloc[index,column]
dataFrame.loc[100:120,['sna','sarea']]
# Out:
#                             sna sarea
# 100  YouBike2.0_捷運大安森林公園站(5號出口)   大安區
# 101           YouBike2.0_信義建國路口   大安區
# 102             YouBike2.0_東豐公園   大安區
# 103     YouBike2.0_德安公園(四維路66巷)   大安區
# 104    YouBike2.0_捷運忠孝復興站(5號出口)   大安區
# 105    YouBike2.0_捷運忠孝敦化站(2號出口)   大安區
# 106    YouBike2.0_捷運忠孝敦化站(7號出口)   大安區
# 107          YouBike2.0_瑞安街208巷   大安區
# 108          YouBike2.0_樂利路21巷口   大安區
# 109  YouBike2.0_捷運科技大樓站(台北教育大學)   大安區
# 110   YouBike2.0_捷運國父紀念館站(2號出口)   大安區
# 111             YouBike2.0_仁愛醫院   大安區
# 112    YouBike2.0_捷運信義安和站(4號出口)   大安區
# 113             YouBike2.0_成功國宅   大安區
# 114           YouBike2.0_仁愛延吉街口   大安區
# 115    YouBike2.0_捷運信義安和站(1號出口)   大安區
# 116      YouBike2.0_敦化南路二段103巷口   大安區
# 117      YouBike2.0_復興南路二段128巷口   大安區
# 118         YouBike2.0_和平東建國南路口   大安區
# 119             YouBike2.0_芳蘭山莊   大安區
# 120      YouBike2.0_復興南路一段126巷口   大安區

# %%
#搜尋欄位值內的資料
#先抓出Series
#bool Series
min = int(input("請輸入要查詢的可借數量:"))
mask = dataFrame['sbi'] <= min
mask_dataFrame = dataFrame[mask]
mask_dataFrame.to_csv('可藉小於3的站點.csv')
filename = f'可借小於{min}的站點.xlsx'
mask_dataFrame.to_excel(filename)

# %%
mask_dataFrame.to_excel('可借小於3的站點.xlsx')
